# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
time = np.linspace(0,1,365*2)
result = np.sin(2*np.pi*12*time)
ds = pd.date_range('2017-01-01', periods = 365*2, freq = 'D')
df = pd.DataFrame({'ds':ds, 'y':result})
df.head()
# Out:
#           ds         y
# 0 2017-01-01  0.000000
# 1 2017-01-02  0.103243
# 2 2017-01-03  0.205382
# 3 2017-01-04  0.305326
# 4 2017-01-05  0.402007

# %%
len(time),time
# Out:
# (730,
#  array([0.        , 0.00137174, 0.00274348, 0.00411523, 0.00548697,
#         0.00685871, 0.00823045, 0.00960219, 0.01097394, 0.01234568,
#         0.01371742, 0.01508916, 0.01646091, 0.01783265, 0.01920439,
#         0.02057613, 0.02194787, 0.02331962, 0.02469136, 0.0260631 ,
#         0.02743484, 0.02880658, 0.03017833, 0.03155007, 0.03292181,
#         0.03429355, 0.03566529, 0.03703704, 0.03840878, 0.03978052,
#         0.04115226, 0.04252401, 0.04389575, 0.04526749, 0.04663923,
#         0.04801097, 0.04938272, 0.05075446, 0.0521262 , 0.05349794,
#         0.05486968, 0.05624143, 0.05761317, 0.05898491, 0.06035665,
#         0.0617284 , 0.06310014, 0.06447188, 0.06584362, 0.06721536,
#         0.06858711, 0.06995885, 0.07133059, 0.07270233, 0.07407407,
#         0.07544582, 0.07681756, 0.0781893 , 0.07956104, 0.08093278,
#         0.08230453, 0.08367627, 0.08504801, 0.08641975, 0.0877915 ,
#         0.08916324, 0.09053498, 0.09190672, 0.09327846, 0.09465021,
# ...

# %%
ds
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10',
#                ...
#                '2018-12-22', '2018-12-23', '2018-12-24', '2018-12-25',
#                '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-29',
#                '2018-12-30', '2018-12-31'],
#               dtype='datetime64[ns]', length=730, freq='D')

# %%
df['y'].plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
# !pip install prophet

# %%
from prophet import Prophet

m = Prophet(yearly_seasonality=True, daily_seasonality= True)
m.fit(df);
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1hjwnd_b/207b1eux.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1hjwnd_b/b66wiygh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30646', 'data', 'file=/tmp/tmp1hjwnd_b/207b1eux.json', 'init=/tmp/tmp1hjwnd_b/b66wiygh.json', 'output', 'file=/tmp/tmp1hjwnd_b/prophet_modelz6qymp61/prophet_model-20240305004628.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 00:46:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 00:46:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future = m.make_future_dataframe(periods = 30)
forecast = m.predict(future)

# %%
m.plot(forecast);

# %%
time = np.linspace(0,1,365*2)
result = np.sin(2*np.pi*12*time) +time
ds = pd.date_range('2017-01-01', periods = 365*2, freq = 'D')
df = pd.DataFrame({'ds':ds, 'y':result})

# %%
df['y'].plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
m = Prophet(yearly_seasonality=True, daily_seasonality= True)
m.fit(df);
future = m.make_future_dataframe(periods = 30)
forecast = m.predict(future)
m.plot(forecast);
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1hjwnd_b/hrr4cg74.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1hjwnd_b/kapmnm8c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2707', 'data', 'file=/tmp/tmp1hjwnd_b/hrr4cg74.json', 'init=/tmp/tmp1hjwnd_b/kapmnm8c.json', 'output', 'file=/tmp/tmp1hjwnd_b/prophet_modelgbs0urzc/prophet_model-20240305005454.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 00:54:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 00:54:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
pinkwink_web = pd.read_excel('./sample_data/pinkwink_web.xlsx',names=['ds','hit'])
pinkwink_web.head()
# Out:
#           ds   hit
# 0 2016-01-01  2332
# 1 2016-01-02  3110
# 2 2016-01-03  3110
# 3 2016-01-04  6742
# 4 2016-01-05  7867

# %%
df = pd.DataFrame({'ds':pd.to_datetime(pinkwink_web['ds'],format="%y. %m. %d."),
                   'y' : pinkwink_web['hit']})
m = Prophet(yearly_seasonality=True, daily_seasonality = True)
m.fit(df)
future = m.make_future_dataframe(periods = 31)
forecast = m.predict(future)
m.plot(forecast);
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1hjwnd_b/05_wdguh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1hjwnd_b/t1s_z4rb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10267', 'data', 'file=/tmp/tmp1hjwnd_b/05_wdguh.json', 'init=/tmp/tmp1hjwnd_b/t1s_z4rb.json', 'output', 'file=/tmp/tmp1hjwnd_b/prophet_model2ow7tq4i/prophet_model-20240305010823.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
pinkwink_web['ds']
# Out:
# 0      2016-01-01
# 1      2016-01-02
# 2      2016-01-03
# 3      2016-01-04
# 4      2016-01-05
#           ...
# 1091   2018-12-27
# 1092   2018-12-28
# 1093   2018-12-29
# 1094   2018-12-30
# 1095   2018-12-31
# Name: ds, Length: 1096, dtype: datetime64[ns]

# %%
ds
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10',
#                ...
#                '2018-12-22', '2018-12-23', '2018-12-24', '2018-12-25',
#                '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-29',
#                '2018-12-30', '2018-12-31'],
#               dtype='datetime64[ns]', length=730, freq='D')

# %%
df
# Out:
#              ds      y
# 0    2016-01-01   2332
# 1    2016-01-02   3110
# 2    2016-01-03   3110
# 3    2016-01-04   6742
# 4    2016-01-05   7867
# ...         ...    ...
# 1091 2018-12-27  12931
# 1092 2018-12-28  10854
# 1093 2018-12-29   7458
# 1094 2018-12-30   6711
# 1095 2018-12-31   8583
#
# [1096 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
sns.set_palette('husl')

plt.figure(figsize=(10,6))
for each in ['trend', 'yhat', 'yhat_lower', 'yhat_upper']:
  plt.plot(forecast['ds'], forecast[each], label = each)

plt.legend(loc='best')
plt.show()

# %%
plt.figure(figsize=(10,6))
for each in ['trend', 'yhat', 'yhat', 'yearly']:
  plt.plot(forecast['ds'], forecast[each], label = each)

plt.legend(loc='best')
plt.show()

# %%
m.plot_components(forecast);

# %%
import yfinance as yf

# %%
KIA = yf.download('035250.KS',start='1990-01-01',end='2023-12-31',)

KIA.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2001-10-26  14299.065430  14299.065430  14299.065430  14299.065430
# 2001-10-29  15981.308594  15981.308594  15700.934570  15981.308594
# 2001-10-30  15887.850586  16448.597656  15093.458008  15981.308594
# 2001-10-31  16214.953125  16308.411133  15514.018555  15560.748047
# 2001-11-01  15560.748047  15700.934570  15000.000000  15093.458008
#
#               Adj Close    Volume
# Date
# 2001-10-26  8123.743164     86670
# 2001-10-29  9079.478516   6989240
# 2001-10-30  9079.478516  22488190
# 2001-10-31  8840.544922   7325220
# 2001-11-01  8575.062500   6980680

# %%
KIA = KIA[["Close"]]
KIA = KIA.reset_index()
KIA.columns = ['ds','y']

KIA.head()
# Out:
#           ds             y
# 0 2001-10-26  14299.065430
# 1 2001-10-29  15981.308594
# 2 2001-10-30  15981.308594
# 3 2001-10-31  15560.748047
# 4 2001-11-01  15093.458008

# %%
m=Prophet()
m.fit(KIA)

future = m.make_future_dataframe(periods=300)
future.tail()
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1hjwnd_b/2b7o1tzs.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1hjwnd_b/9f0jodm7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98050', 'data', 'file=/tmp/tmp1hjwnd_b/2b7o1tzs.json', 'init=/tmp/tmp1hjwnd_b/9f0jodm7.json', 'output', 'file=/tmp/tmp1hjwnd_b/prophet_model_icjqmcv/prophet_model-20240305014334.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:43:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:43:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#              ds
# 5839 2024-10-19
# 5840 2024-10-20
# 5841 2024-10-21
# 5842 2024-10-22
# 5843 2024-10-23

# %%
forecast = m.predict(future)
forecast.head()
# Out:
#           ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0 2001-10-26  15502.197500  12572.519479  18876.525784  15502.197500
# 1 2001-10-29  15480.495940  12721.500080  18800.318857  15480.495940
# 2 2001-10-30  15473.262086  12619.297515  18864.524734  15473.262086
# 3 2001-10-31  15466.028233  12918.355306  19123.299978  15466.028233
# 4 2001-11-01  15458.794379  12539.627790  18971.181642  15458.794379
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  15502.197500      269.329976            269.329976            269.329976
# 1  15480.495940      280.416305            280.416305            280.416305
# 2  15473.262086      341.734905            341.734905            341.734905
# 3  15466.028233      366.857686            366.857686            366.857686
# 4  15458.794379      387.681003            387.681003            387.681003
#
#        weekly  weekly_lower  weekly_upper     yearly  yearly_lower  \
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(KIA['ds'],KIA['y'])
plt.show()

# %%
m.plot(forecast);

# %%
m.plot_components(forecast);
