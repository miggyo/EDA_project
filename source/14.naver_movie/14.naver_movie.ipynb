# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
import urllib
from urllib.request import Request
from user_agent import generate_user_agent
# Out:
# /tmp/ipykernel_15419/2398869997.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
url="https://search.naver.com/search.naver?query={search_word1}+{search_word2}"
req=Request(url.format(search_word1=urllib.parse.quote("박스오피스"),
                       search_word2=urllib.parse.quote("평점순")),headers = {'User-Agent':generate_user_agent()})
res = urlopen(req)
soup = BeautifulSoup(res,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="always" name="referrer"/>
#   <meta content="telephone=no,address=no,email=no" name="format-detection"/>
#   <meta content="박스오피스 평점순 : 네이버 통합검색" property="og:title">
#    <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/>
#    <meta content="'박스오피스 평점순'의 네이버 통합검색 결과입니다." property="og:description"/>
#    <meta content="'박스오피스 평점순'의 네이버 통합검색 결과입니다." lang="ko" name="description"/>
#    <title>
#     박스오피스 평점순 : 네이버 통합검색
#    </title>
#    <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/>
#    <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml">
#     <script>
#      if (top.frames.length!=0 || window!=top) window.open(location, "_top");
#     </script>
# ...

# %%
rating = soup.find(class_="_panel_rating _tab_content")
for each in rating.find_all("li"):
    print(each.prettify())
# Out:
# <li>
#  <a class="inner" href="?where=nexearch&amp;sm=tab_etc&amp;mra=bkEw&amp;pkid=68&amp;os=33523225&amp;qvt=0&amp;query=%EA%B1%B4%EA%B5%AD%EC%A0%84%EC%9F%81" nocr="" onclick="return goOtherCR(this, 'a=nco_x0a*M.boxschinfo&amp;r=1&amp;i=1800009D_000000000000&amp;u=' + urlencode(this.href));">
#   <div class="item">
#    <div class="thumb">
#     <span class="cm_thumb_rank_number">
#      <span class="this_bg">
#      </span>
#      <span class="this_text">
#       1
#      </span>
#     </span>
#     <img alt="건국전쟁" height="145" onerror="this.src='https://ssl.pstatic.net/sstatic/keypage/outside/scui/weboriginal_new/im/no_img.png'" src="https://search.pstatic.net/common?type=f&amp;size=206x290&amp;quality=100&amp;direct=true&amp;src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20240206_234%2F1707210318193MxCbW_JPEG%2Fmovie_image.jpg" width="103"/>
#    </div>
#    <div class="title_box">
#     <strong class="name">
#      건국전쟁
#     </strong>
#     <span class="sub_text">
# ...

# %%
prefix = "https://search.naver.com/search.naver"
movie_list = []

rating = soup.find(class_="_panel_rating _tab_content")
for idx, each1 in enumerate(rating.find_all("li")):
    movie = []
    print("[" + str(idx) + "]")
    print("title : " + each1.find("strong", class_="name").get_text())
    print("rating : " + each1.find("span", class_="sub_text").get_text())
    print("link : " + prefix + each1.find("a")["href"])
# Out:
# [0]
# title : 건국전쟁
# rating : 9.70
# link : https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=33523225&qvt=0&query=%EA%B1%B4%EA%B5%AD%EC%A0%84%EC%9F%81
# [1]
# title : 서울의 봄
# rating : 9.52
# link : https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=25517275&qvt=0&query=%EC%84%9C%EC%9A%B8%EC%9D%98%20%EB%B4%84
# [2]
# title : 이프 온리
# rating : 9.18
# link : https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=1777331&qvt=0&query=%EC%9D%B4%ED%94%84%20%EC%98%A8%EB%A6%AC
# [3]
# title : 월레스와 그로밋 더 클래식 ...
# rating : 9.16
# link : https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=33624610&qvt=0&query=%EC%9B%94%EB%A0%88%EC%8A%A4%EC%99%80%20%EA%B7%B8%EB%A1%9C%EB%B0%8B%20%EB%8D%94%20%ED%81%B4%EB%9E%98%EC%8B%9D%20%EC%BB%AC%EB%A0%89%EC%85%98
# [4]
# title : 화양연화
# rating : 9.12
# ...

# %%
prefix = "https://search.naver.com/search.naver"
movie_list = []

rating = soup.find(class_="_panel_rating _tab_content")
for idx, each1 in enumerate(rating.find_all("li")):
    movie = []
    movie.append(each1.find("strong", class_="name").string)
    movie.append(each1.find("span", class_="sub_text").get_text())
    movie.append(prefix + each1.find("a")["href"])

    movie_list.append(movie)

movie_list
# Out:
# [['건국전쟁',
#   '9.70',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=33523225&qvt=0&query=%EA%B1%B4%EA%B5%AD%EC%A0%84%EC%9F%81'],
#  ['서울의 봄',
#   '9.52',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=25517275&qvt=0&query=%EC%84%9C%EC%9A%B8%EC%9D%98%20%EB%B4%84'],
#  ['이프 온리',
#   '9.18',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=1777331&qvt=0&query=%EC%9D%B4%ED%94%84%20%EC%98%A8%EB%A6%AC'],
#  ['월레스와 그로밋 더 클래식 ...',
#   '9.16',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=33624610&qvt=0&query=%EC%9B%94%EB%A0%88%EC%8A%A4%EC%99%80%20%EA%B7%B8%EB%A1%9C%EB%B0%8B%20%EB%8D%94%20%ED%81%B4%EB%9E%98%EC%8B%9D%20%EC%BB%AC%EB%A0%89%EC%85%98'],
#  ['화양연화',
#   '9.12',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=1766857&qvt=0&query=%ED%99%94%EC%96%91%EC%97%B0%ED%99%94'],
# ...

# %%
res = urlopen(movie_list[3][2])
soup = BeautifulSoup(res,"html.parser")
print(soup.find("strong",class_="_text"))
# Out:
# <strong class="_text">월레스와 그로밋 더 클래식 컬렉션</strong>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="always" name="referrer"/>
#   <meta content="telephone=no,address=no,email=no" name="format-detection"/>
#   <meta content="월레스와 그로밋 더 클래식 컬렉션 : 네이버 통합검색" property="og:title">
#    <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/>
#    <meta content="'월레스와 그로밋 더 클래식 컬렉션'의 네이버 통합검색 결과입니다." property="og:description"/>
#    <meta content="'월레스와 그로밋 더 클래식 컬렉션'의 네이버 통합검색 결과입니다." lang="ko" name="description"/>
#    <title>
#     월레스와 그로밋 더 클래식 컬렉션 : 네이버 통합검색
#    </title>
#    <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/>
#    <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml">
#     <script>
#      if (top.frames.length!=0 || window!=top) window.open(location, "_top");
#     </script>
# ...

# %%
def get_title(url):
    res = urlopen(url)
    soup = BeautifulSoup(res, "html.parser")
    return soup.find("strong",class_="_text").string

# %%
movie
# Out:
# ['플랜 75',
#  '7.47',
#  'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=26405053&qvt=0&query=%ED%94%8C%EB%9E%9C%2075']

# %%
import time

for movie in movie_list:
    movie[0] = get_title(movie[2])
    time.sleep(0.5)


movie_list
# Out:
# [['건국전쟁',
#   '9.70',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=33523225&qvt=0&query=%EA%B1%B4%EA%B5%AD%EC%A0%84%EC%9F%81'],
#  ['서울의 봄',
#   '9.52',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=25517275&qvt=0&query=%EC%84%9C%EC%9A%B8%EC%9D%98%20%EB%B4%84'],
#  ['이프 온리',
#   '9.18',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=1777331&qvt=0&query=%EC%9D%B4%ED%94%84%20%EC%98%A8%EB%A6%AC'],
#  ['월레스와 그로밋 더 클래식 컬렉션',
#   '9.16',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=33624610&qvt=0&query=%EC%9B%94%EB%A0%88%EC%8A%A4%EC%99%80%20%EA%B7%B8%EB%A1%9C%EB%B0%8B%20%EB%8D%94%20%ED%81%B4%EB%9E%98%EC%8B%9D%20%EC%BB%AC%EB%A0%89%EC%85%98'],
#  ['화양연화',
#   '9.12',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=1766857&qvt=0&query=%ED%99%94%EC%96%91%EC%97%B0%ED%99%94'],
# ...

# %%
df = pd.DataFrame(movie_list, columns=['name','rating','link'])

df
# Out:
#                                     name rating  \
# 0                                   건국전쟁   9.70
# 1                                  서울의 봄   9.52
# 2                                  이프 온리   9.18
# 3                     월레스와 그로밋 더 클래식 컬렉션   9.16
# 4                                   화양연화   9.12
# 5                                   중경삼림   9.06
# 6                                     괴물   9.06
# 7                                     소풍   9.04
# 8                             사운드 오브 프리덤   8.92
# 9                                  오펜하이머   8.53
# 10                               바튼 아카데미   8.52
# 11                                  시민덕희   8.43
# 12                                    파묘   8.35
# 13                                추락의 해부   8.32
# 14                                 도그데이즈   8.17
# 15                               스노우 퍼핀즈   8.13
# 16        귀멸의 칼날: 인연의 기적, 그리고 합동 강화 훈련으로   8.10
# 17  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~   7.99
# ...
