# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# %%
driver = webdriver.Chrome(service=Service("../../driver/chromedriver-linux64/chromedriver"))
driver.get("https://www.selenium.dev/")

# %%
driver.current_url
# Out:
# 'https://www.selenium.dev/'

# %%
driver.execute_script("window.scrollTo(0,0)")

# %%
from selenium.webdriver.common.by import By

element = driver.find_element(By.CLASS_NAME,"d-flex.justify-content-center.p-5.td-box--100")
print(element.get_attribute('innerHTML'))
# Out:
# <h2 class="selenium">News</h2>

# %%
child = element.find_element(By.CLASS_NAME, "selenium")

print(child.text)
# Out:
# News

# %%
driver.execute_script("arguments[0].scrollIntoView(false);",child)

# %%
child
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.B0E376345A5B7744C6C69E8F253BFE63.e.67")>

# %%
driver.save_screenshot("../../data/16.selenium/image_01.png")
# Out:
# True

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

image = mpimg.imread("../../data/16.selenium/image_01.png")
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
doc_link=driver.find_element(By.XPATH, '''//*[@id="main_navbar"]/ul/li[3]/a''')
doc_link.click()

# %%
search_btn = driver.find_element(By.XPATH, '''//*[@id="docsearch-1"]/button''')
search_btn.click()

# %%
from selenium.webdriver.common.keys import Keys

search_doc = driver.find_element(By.CSS_SELECTOR, "#docsearch-input")
search_doc.send_keys('find elements')

# %%
search_doc
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.148A779F88E40E00C3EF66EFE26007C5.e.103")>

# %%
search_doc.send_keys(Keys.ENTER)

# %%
python_tab = driver.find_element(By.ID,"tabs-09-02-tab")
driver.execute_script("arguments[0].scrollIntoView(false);",python_tab)

# %%
python_tab.click()

# %%
python_panel = driver.find_element(By.ID, "tabs-09-02")
python_code = python_panel.find_element(By.TAG_NAME,"code")

print(python_code.text)
# Out:
# from selenium import webdriver
# from selenium.webdriver.common.by import By
#
# driver = webdriver.Chrome()
# driver.get("https://www.example.com")
#
#     # Get element with tag name 'div'
# element = driver.find_element(By.TAG_NAME, 'div')
#
#     # Get all the elements available with tag name 'p'
# elements = element.find_elements(By.TAG_NAME, 'p')
# for e in elements:
#     print(e.text)

# %%
driver.back()

# %%
menu = driver.find_element(By.ID,"main_navbar")
li_list = menu.find_elements(By.TAG_NAME,"li")
for idx, li in enumerate(li_list) : 
    print("[" +  str(idx)  +"  ]  =============================")
    print(li.get_attribute('innerHTML'))
# Out:
# [0  ]  =============================
# <a class="nav-link dropdown-toggle" href="#" id="navbarDropdown" role="button" data-bs-toggle="dropdown" aria-haspopup="true" aria-expanded="false">About</a><div class="dropdown-menu" aria-labelledby="navbarDropdown"><a class="dropdown-item" href="/about">About Selenium</a>
# <a class="dropdown-item" href="/project">Structure and Governance</a>
# <a class="dropdown-item" href="/events">Events</a>
# <a class="dropdown-item" href="/ecosystem">Ecosystem</a>
# <a class="dropdown-item" href="/history">History</a>
# <a class="dropdown-item" href="/getinvolved">Get Involved</a>
# <a class="dropdown-item" href="/sponsors">Sponsors</a></div>
# [1  ]  =============================
# <a class="nav-link" href="/downloads"><span>Downloads</span></a>
# [2  ]  =============================
# <a class="nav-link" href="/documentation"><span>Documentation</span></a>
# [3  ]  =============================
# <a class="nav-link" href="/projects"><span>Projects</span></a>
# [4  ]  =============================
# <a class="nav-link" href="/support"><span>Support</span></a>
# [5  ]  =============================
# <a class="nav-link" href="/blog"><span>Blog</span></a>
# [6  ]  =============================
# <div class="dropdown"><a class="nav-link dropdown-toggle" href="#" role="button" data-bs-toggle="dropdown" aria-haspopup="true" aria-expanded="false">English</a><ul class="dropdown-menu"><li><a class="dropdown-item" href="/pt-br/documentation/">Português (Brasileiro)</a></li><li><a class="dropdown-item" href="/zh-cn/documentation/">中文简体</a></li><li><a class="dropdown-item" href="/ja/documentation/">日本語</a></li><li><a class="dropdown-item" href="/other/documentation/">Other</a></li></ul></div>
# [7  ]  =============================
# <a class="dropdown-item" href="/pt-br/documentation/">Português (Brasileiro)</a>
# [8  ]  =============================
# <a class="dropdown-item" href="/zh-cn/documentation/">中文简体</a>
# [9  ]  =============================
# <a class="dropdown-item" href="/ja/documentation/">日本語</a>
# [10  ]  =============================
# <a class="dropdown-item" href="/other/documentation/">Other</a>

# %%
about = li_list[]
about.click()
link_list = about.find_elements(By.CLASS_NAME,"dropdown-item")
for link in link_list:
    print(link.text)
# Out:
# About Selenium
# Structure and Governance
# Events
# Ecosystem
# History
# Get Involved
# Sponsors

# %%
len(li_list)
# Out:
# 11

# %%
li_list
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.741AC10D8E0815EA73552A08B9374CD3.e.238")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.741AC10D8E0815EA73552A08B9374CD3.e.262")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.741AC10D8E0815EA73552A08B9374CD3.e.263")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.741AC10D8E0815EA73552A08B9374CD3.e.264")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.741AC10D8E0815EA73552A08B9374CD3.e.265")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.741AC10D8E0815EA73552A08B9374CD3.e.266")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.741AC10D8E0815EA73552A08B9374CD3.e.239")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.741AC10D8E0815EA73552A08B9374CD3.e.267")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.741AC10D8E0815EA73552A08B9374CD3.e.268")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.741AC10D8E0815EA73552A08B9374CD3.e.269")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.741AC10D8E0815EA73552A08B9374CD3.e.270")>]

# %%
history = about.find_element(By.LINK_TEXT,"History")
print(history.text)
# Out:
# History

# %%
history
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5083daeff4f0dd996068d5f3a49ed390", element="f.5EFC1C44C51D1BC93B7859E7185121CA.d.741AC10D8E0815EA73552A08B9374CD3.e.275")>

# %%
history.click()

# %%
driver.back()

# %%
driver.close()
